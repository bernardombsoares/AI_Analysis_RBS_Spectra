# %%
import torch
import numpy as np
import numpy
import matplotlib.pyplot as plt
import re
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn import datasets
import ast

# %%
i=100
x,y=[],[]
while i<=400:
    f=pd.read_csv('./samples/'+str(i)+'.csv',delimiter='\t')
    x.append(f)
    i+=50
y.append(pd.read_csv('./samples/test_280',delimiter='\t'))
y[0].drop(['channel','experimental','smoothed','Au','197Au'],axis=1,inplace=True)
for i in range(len(x)):
    x[i].drop(['channel','experimental','smoothed','Au','197Au'],axis=1,inplace=True)
for i in range(len(x)):
    x[i] = x[i].to_numpy()
y = y[0].to_numpy()
x
# Out:
# [array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
#         [0.        ],
#         [0.        ],
#         ...,
#         [0.05017025],
#         [0.0230097 ],
#         [0.00914428]]),
#  array([[0.        ],
# ...

# %%
x_train,x_test=[],[]
aux=[]
for i in range(len(x)):
    aux=[]
    for j in range(len(x[i])):
        aux.append(x[i][j][0])
    aux/=sum(aux)
    x_train.append(aux)


aux=[]
for i in range(1700,len(y)):
    aux.append(y[i][0])
x_test.append(aux)


data_array=np.array(x_train)
data_array_test=np.array(x_test)
labels_array=np.array([100,150,200,250,300,350,400])
labels_array_test=np.array([280])


print('Numero de espetros: '+ str(len(data_array)))
print('Numero de bins em cada espetro: '+str(len(data_array[0])))
print(data_array)
print('\n')
print(labels_array)
# Out:
# Numero de espetros: 7
# Numero de bins em cada espetro: 1878
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 6.06968309e-08
#   2.78375248e-08 1.10629008e-08]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.03530593e-08
#   1.85072148e-08 7.35494565e-09]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 3.01811972e-08
#   1.38420707e-08 5.50097240e-09]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.00092965e-08
#   9.17690889e-09 3.64699210e-09]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.71030069e-08
#   7.84399071e-09 3.11727756e-09]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.49232669e-08
#   6.84429164e-09 2.71998750e-09]]
#
#
# [100 150 200 250 300 350 400]

# %%
from tensorflow import keras
model=keras.models.Sequential(
    [keras.layers.Dense(200,activation='relu',input_shape=(1878,)),
     keras.layers.Dense(100,activation='relu'),
     keras.layers.Dense(1,activation='sigmoid')]
     )

model.compile(
    loss='Poisson', optimizer='adam', metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_92 (Dense)            (None, 200)               375800
#
#  dense_93 (Dense)            (None, 100)               20100
#
#  dense_94 (Dense)            (None, 1)                 101
#
# ...
# Total params: 396001 (1.51 MB)
# Trainable params: 396001 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(data_array,labels_array,epochs=500,batch_size=32)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9131 - accuracy: 0.0000e+00
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8942 - accuracy: 0.0000e+00
# Epoch 3/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.8762 - accuracy: 0.0000e+00
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8588 - accuracy: 0.0000e+00
# Epoch 5/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8420 - accuracy: 0.0000e+00
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8259 - accuracy: 0.0000e+00
# Epoch 7/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8103 - accuracy: 0.0000e+00
# Epoch 8/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7953 - accuracy: 0.0000e+00
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.7807 - accuracy: 0.0000e+00
# Epoch 10/500
# ...

# %%
preds= model.predict(x_test)
accuracy_score(y_test,preds.round())
# Out:
# 1/1 [==============================] - 0s 110ms/step
# 0.0
